# %%
import pandas as pd

# Loading Customers(Excel) data
plans = pd.read_csv(r"C:\Users\Ravi Kumar\Downloads\Telecom_jupyter\Original data set\plans.csv")
display(plans)
# Out:
#    PlanID  PlanType  MonthlyCost  DataLimitGB  VoiceMinutes  SMSLimit
# 0       1     Basic          199          1.5           300       100
# 1       2  Standard          399          3.0           800       500
# 2       3   Premium          699         10.0          2000      2000

# %%
# Cross checking column names,finding null values,improper text,Changing data types,Distinct Values 
print(plans.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PlanID        3 non-null      int64
#  1   PlanType      3 non-null      object
#  2   MonthlyCost   3 non-null      int64
#  3   DataLimitGB   3 non-null      float64
#  4   VoiceMinutes  3 non-null      int64
#  5   SMSLimit      3 non-null      int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 276.0+ bytes
# None

# %%
#EVerything is okay
#converting Total cleaned data set into CSV
plans.to_csv("plans_cleaned_final.csv", index=False)
